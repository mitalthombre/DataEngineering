# %%
import pandas as pd
import requests
from datetime import datetime, timedelta

# %%
url = "https://aerodatabox.p.rapidapi.com/flights/airports/icao/EHAM/2022-11-05T20:00/2022-11-06T08:00"

querystring = {"withLeg":"true","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"false"}

headers = {
	"X-RapidAPI-Key": "b409d718a7mshf46e85a187fe9c0p179890jsn8fd66df75a29",
	"X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"departures":[{"departure":{"scheduledTimeLocal":"2022-11-05 20:35+01:00","actualTimeLocal":"2022-11-05 20:35+01:00","scheduledTimeUtc":"2022-11-05 19:35Z","actualTimeUtc":"2022-11-05 19:35Z","quality":["Basic","Live"]},"arrival":{"airport":{"icao":"KORD","iata":"ORD","name":"Chicago"},"quality":[]},"number":"5Y 8154","status":"Expected","codeshareStatus":"IsOperator","isCargo":true,"aircraft":{"reg":"N489MC","modeS":"A60B1E","model":"Boeing 747"},"airline":{"name":"Atlas Air"}},{"departure":{"scheduledTimeLocal":"2022-11-05 20:35+01:00","actualTimeLocal":"2022-11-05 20:35+01:00","scheduledTimeUtc":"2022-11-05 19:35Z","actualTimeUtc":"2022-11-05 19:35Z","terminal":"1","checkInDesk":"6-8","quality":["Basic","Live"]},"arrival":{"airport":{"icao":"LFMN","iata":"NCE","name":"Nice"},"quality":[]},"number":"AF 8271","status":"Expected","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Embraer 190"},"airline":{"name":"Air France"}},{"departure":{"scheduledTimeLocal":"2022-11-05 20:55+01:00","actualTimeLocal":"2022-11-05 20:55+01:00","scheduledTimeUtc":"2022-11-05 19:55Z","actualTimeUtc":"2022-11-05 19:55Z","terminal":"1","checkInDesk":"6-8","quality":["Basic","Live"]},"arrival":{"airport":{"icao":"ENCN","iata":"KRS","name":"Kjevik"},"quality":[]},"number":"AF 8279","status":"Expected","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Embraer 175"},"airline":{"name":"Air France"}},{"departure":{"scheduledTimeLocal":"2022-11-05 20:25+01:00","actualTimeLocal":"2022-11-05 20:25+01:00","scheduledTimeUtc":"2022-11-05 19:25Z","actualTimeUtc":"2022-11-05 19:25Z","terminal":"1","checkInDesk":"6-8","quality":["Basic","Live"]},"arrival":{"airport":{"icao":"LFBD","iata":"BOD","name":"Bordeaux/Mérignac"},"quality":[]},"number":"AF 8287","status":"Expected","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Embraer 190"},"airline":{"name":"Air France"}},{"departure":{"scheduledTimeLocal":"2022-11-05 20:25+01:00","actualTimeLocal":"2022-11-05 20:25+01:00","scheduledTimeUtc":"2022-11-05 19:25Z","actualTimeUtc":"2022-11-05 19:25Z","terminal":"1","checkInDesk":"6-8","quality":["Basic","Live"]},"arrival":{"airport":{"icao":"LFRS","iata":"NTE","name":"Nantes"},"quality":[]},"number":"AF 8307","status":"Expected","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Embraer 190"},"airline":{"name":"Air France"}},{"departure":{"scheduledTimeLocal":"2022-11-05 20:35+01:00","actualTimeLocal":"2022-11-05 20:35+01:00","scheduledTimeUtc":"2022-11-05 19:35Z","actualTimeUtc":"2022-11-05 19:35Z","terminal":"1","checkInDesk":"6-8","quality":["Basic","Live"]},"arrival":{"airport":{"icao":"LFLL","iata":"LYS","name":"Lyon"},"quality":[]},"number":"AF 8321","status":"Expected","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Embraer 195-E2"},"airline":{"name":"Air France"}},{"departure":{"scheduledTimeLocal":"2022-11-05 20:35+01:00","actualTimeLocal":"2022-11-05 20:35+01:00","scheduledTimeUtc":"2022-11-05 19:35Z","actualTimeUtc":"2022-11-05 19:35Z","terminal":"1","checkInDesk":"6-8","quality":["Basic","Live"]},"arrival":{"airport":{"icao":"LFSB","iata":"BSL","name":"Bâle/Mulhouse"},"quality":[]},"number":"AF 8345","status":"Expected","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"model":"Embraer 175"},"airline":{"name":"Air France"}},{"departure":{"scheduledTimeLocal":"2022-11-05 20:55+01:00","actualTimeLocal":"2022-11-05 20:55+01:00","scheduledTimeUtc":"2022-11-05 19:55Z","actualTimeUtc":"2022-11-05 19:55Z","terminal":"2","checkInDesk":"9-16","quality":["Basic","Live"]},"arrival":{"airport":{"icao":"VTBS","iata":"BKK","name":"Bangkok"},"quality":[]},"number":"AF 8391","status":"Expected","codeshareStatus":"IsCodeshared","isCargo":false,"aircraft":{"reg":"PH-BVG","modeS":"484CBB","model":"Boeing 777"},"airline":{"name":"Air France"}},{"departure":{"scheduledTimeLocal":"2022-11-05 20:45+01:00","actualTimeLocal":"2022-11-05 20:45+01:00","scheduledTimeUtc":"202 ...

# %%
response.json()
# Out:
# {'departures': [{'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'KORD', 'iata': 'ORD', 'name': 'Chicago'},
#     'quality': []},
#    'number': '5Y 8154',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': True,
#    'aircraft': {'reg': 'N489MC', 'modeS': 'A60B1E', 'model': 'Boeing 747'},
#    'airline': {'name': 'Atlas Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'number': 'AF 8271',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ENCN', 'iata': 'KRS', 'name': 'Kjevik'},
#     'quality': []},
#    'number': 'AF 8279',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:25+01:00',
#     'actualTimeLocal': '2022-11-05 20:25+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:25Z',
#     'actualTimeUtc': '2022-11-05 19:25Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFBD',
#      'iata': 'BOD',
#      'name': 'Bordeaux/Mérignac'},
#     'quality': []},
#    'number': 'AF 8287',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:25+01:00',
#     'actualTimeLocal': '2022-11-05 20:25+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:25Z',
#     'actualTimeUtc': '2022-11-05 19:25Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFRS', 'iata': 'NTE', 'name': 'Nantes'},
#     'quality': []},
#    'number': 'AF 8307',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFLL', 'iata': 'LYS', 'name': 'Lyon'},
#     'quality': []},
#    'number': 'AF 8321',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 195-E2'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse'},
#     'quality': []},
#    'number': 'AF 8345',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '2',
#     'checkInDesk': '9-16',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'VTBS', 'iata': 'BKK', 'name': 'Bangkok'},
#     'quality': []},
#    'number': 'AF 8391',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BVG', 'modeS': '484CBB', 'model': 'Boeing 777'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:45+01:00',
#     'actualTimeLocal': '2022-11-05 20:45+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:45Z',
#     'actualTimeUtc': '2022-11-05 19:45Z',
#     'terminal': '2',
#     'checkInDesk': '9-16',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'WMKK',
#      'iata': 'KUL',
#      'name': 'Kuala Lumpur'},
#     'quality': []},
#    'number': 'AF 8399',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BQF', 'modeS': '48436D', 'model': 'Boeing 777'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '2',
#     'checkInDesk': '9-16',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo'},
#     'quality': []},
#    'number': 'AF 8425',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXR', 'modeS': '48418C', 'model': 'Boeing 737'},
#    'airline': {'name': 'Air France'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:25+01:00',
#     'actualTimeLocal': '2022-11-05 20:25+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:25Z',
#     'actualTimeUtc': '2022-11-05 19:25Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'quality': []},
#    'number': 'AM 6025',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-GTAU', 'modeS': '394C14', 'model': 'Airbus A321'},
#    'airline': {'name': 'Aeromexico'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LIPZ', 'iata': 'VCE', 'name': 'Venice'},
#     'quality': []},
#    'number': 'AM 6242',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Aeromexico'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDB', 'iata': 'BER', 'name': 'Berlin'},
#     'quality': []},
#    'number': 'AM 6540',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCA', 'modeS': '484CB4', 'model': 'Boeing 737'},
#    'airline': {'name': 'Aeromexico'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'quality': []},
#    'number': 'AM 6556',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCD', 'modeS': '484FDE', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Aeromexico'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'quality': []},
#    'number': 'AM 6558',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCE', 'modeS': '484FDF', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Aeromexico'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:40+01:00',
#     'actualTimeLocal': '2022-11-05 20:40+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:40Z',
#     'actualTimeUtc': '2022-11-05 19:40Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDH', 'iata': 'HAM', 'name': 'Hamburg'},
#     'quality': []},
#    'number': 'AM 6638',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXK', 'modeS': '484163', 'model': 'Boeing 737'},
#    'airline': {'name': 'Aeromexico'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:30+01:00',
#     'actualTimeLocal': '2022-11-05 20:30+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:30Z',
#     'actualTimeUtc': '2022-11-05 19:30Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#     'quality': []},
#    'number': 'AZ 3760',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCL', 'modeS': '485A35', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Alitalia'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ENCN', 'iata': 'KRS', 'name': 'Kjevik'},
#     'quality': []},
#    'number': 'AZ 3774',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Alitalia'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:50+01:00',
#     'actualTimeLocal': '2022-11-05 20:50+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:50Z',
#     'actualTimeUtc': '2022-11-05 19:50Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ESGG', 'iata': 'GOT', 'name': 'Goteborg'},
#     'quality': []},
#    'number': 'EY 5842',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXW', 'modeS': '484555', 'model': 'Boeing 737'},
#    'airline': {'name': 'Etihad Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'number': 'EY 7316',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Etihad Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:30+01:00',
#     'actualTimeLocal': '2022-11-05 20:30+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:30Z',
#     'actualTimeUtc': '2022-11-05 19:30Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#     'quality': []},
#    'number': 'EY 7326',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCL', 'modeS': '485A35', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Etihad Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:40+01:00',
#     'actualTimeLocal': '2022-11-05 20:40+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:40Z',
#     'actualTimeUtc': '2022-11-05 19:40Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDH', 'iata': 'HAM', 'name': 'Hamburg'},
#     'quality': []},
#    'number': 'EY 7386',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXK', 'modeS': '484163', 'model': 'Boeing 737'},
#    'airline': {'name': 'Etihad Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'quality': []},
#    'number': 'EY 7419',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCD', 'modeS': '484FDE', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Etihad Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'number': 'DL 9484',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '2',
#     'checkInDesk': '9-16',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo'},
#     'quality': []},
#    'number': 'DL 9575',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXR', 'modeS': '48418C', 'model': 'Boeing 737'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:25+01:00',
#     'actualTimeLocal': '2022-11-05 20:25+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:25Z',
#     'actualTimeUtc': '2022-11-05 19:25Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'quality': []},
#    'number': 'G3 5046',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-GTAU', 'modeS': '394C14', 'model': 'Airbus A321'},
#    'airline': {'name': 'Gol'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LIPZ', 'iata': 'VCE', 'name': 'Venice'},
#     'quality': []},
#    'number': 'G3 5576',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Gol'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse'},
#     'quality': []},
#    'number': 'G3 5592',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Gol'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ENCN', 'iata': 'KRS', 'name': 'Kjevik'},
#     'quality': []},
#    'number': 'G3 5606',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Gol'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:50+01:00',
#     'actualTimeLocal': '2022-11-05 20:50+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:50Z',
#     'actualTimeUtc': '2022-11-05 19:50Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ESGG', 'iata': 'GOT', 'name': 'Goteborg'},
#     'quality': []},
#    'number': 'G3 5663',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXW', 'modeS': '484555', 'model': 'Boeing 737'},
#    'airline': {'name': 'Gol'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'quality': []},
#    'number': 'G3 5677',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCD', 'modeS': '484FDE', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Gol'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:50+01:00',
#     'actualTimeLocal': '2022-11-05 20:50+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:50Z',
#     'actualTimeUtc': '2022-11-05 19:50Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LKPR', 'iata': 'PRG', 'name': 'Prague'},
#     'quality': []},
#    'number': 'GA 9362',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXN', 'modeS': '484166', 'model': 'Boeing 737'},
#    'airline': {'name': 'Garuda Indonesia'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:25+01:00',
#     'actualTimeLocal': '2022-11-05 20:25+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:25Z',
#     'actualTimeUtc': '2022-11-05 19:25Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'quality': []},
#    'number': 'GA 9511',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-GTAU', 'modeS': '394C14', 'model': 'Airbus A321'},
#    'airline': {'name': 'Garuda Indonesia'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'quality': []},
#    'number': 'GA 9520',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCE', 'modeS': '484FDF', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Garuda Indonesia'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'number': 'GA 9526',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Garuda Indonesia'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:40+01:00',
#     'actualTimeLocal': '2022-11-05 20:40+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:40Z',
#     'actualTimeUtc': '2022-11-05 19:40Z',
#     'terminal': '3',
#     'checkInDesk': '20',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'OMAA',
#      'iata': 'AUH',
#      'name': 'Abu Dhabi Island and Internal Islands City'},
#     'quality': []},
#    'number': 'GF 5102',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'Gulf Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDB', 'iata': 'BER', 'name': 'Berlin'},
#     'quality': []},
#    'number': 'KE 6429',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCA', 'modeS': '484CB4', 'model': 'Boeing 737'},
#    'airline': {'name': 'Korean Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'quality': []},
#    'number': 'KE 6433',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCD', 'modeS': '484FDE', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Korean Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:40+01:00',
#     'actualTimeLocal': '2022-11-05 20:40+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:40Z',
#     'actualTimeUtc': '2022-11-05 19:40Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDH', 'iata': 'HAM', 'name': 'Hamburg'},
#     'quality': []},
#    'number': 'KE 6437',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXK', 'modeS': '484163', 'model': 'Boeing 737'},
#    'airline': {'name': 'Korean Air'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:25+01:00',
#     'actualTimeLocal': '2022-11-05 20:25+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:25Z',
#     'actualTimeUtc': '2022-11-05 19:25Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFBD',
#      'iata': 'BOD',
#      'name': 'Bordeaux/Mérignac'},
#     'quality': []},
#    'number': 'KL 1319',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:25+01:00',
#     'actualTimeLocal': '2022-11-05 20:25+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:25Z',
#     'actualTimeUtc': '2022-11-05 19:25Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'quality': []},
#    'number': 'KL 2023',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-GTAU', 'modeS': '394C14', 'model': 'Airbus A321'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:40+01:00',
#     'actualTimeLocal': '2022-11-05 20:40+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:40Z',
#     'actualTimeUtc': '2022-11-05 19:40Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFML', 'iata': 'MRS', 'name': 'Marseille'},
#     'quality': []},
#    'number': 'KL 3600',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:40+01:00',
#     'actualTimeLocal': '2022-11-05 20:40+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:40Z',
#     'actualTimeUtc': '2022-11-05 19:40Z',
#     'terminal': '3',
#     'checkInDesk': '20',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'OMAA',
#      'iata': 'AUH',
#      'name': 'Abu Dhabi Island and Internal Islands City'},
#     'quality': []},
#    'number': 'KL 3948',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ENGM', 'iata': 'OSL', 'name': 'Oslo'},
#     'quality': []},
#    'number': 'KQ 1151',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCD', 'modeS': '484FDE', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:50+01:00',
#     'actualTimeLocal': '2022-11-05 20:50+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:50Z',
#     'actualTimeUtc': '2022-11-05 19:50Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ESGG', 'iata': 'GOT', 'name': 'Goteborg'},
#     'quality': []},
#    'number': 'KQ 1163',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXW', 'modeS': '484555', 'model': 'Boeing 737'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:30+01:00',
#     'actualTimeLocal': '2022-11-05 20:30+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:30Z',
#     'actualTimeUtc': '2022-11-05 19:30Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#     'quality': []},
#    'number': 'KQ 1171',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCL', 'modeS': '485A35', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ENCN', 'iata': 'KRS', 'name': 'Kjevik'},
#     'quality': []},
#    'number': 'KQ 1211',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'number': 'KQ 1263',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:25+01:00',
#     'actualTimeLocal': '2022-11-05 20:25+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:25Z',
#     'actualTimeUtc': '2022-11-05 19:25Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFBD',
#      'iata': 'BOD',
#      'name': 'Bordeaux/Mérignac'},
#     'quality': []},
#    'number': 'KQ 1319',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:50+01:00',
#     'actualTimeLocal': '2022-11-05 20:50+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:50Z',
#     'actualTimeUtc': '2022-11-05 19:50Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LKPR', 'iata': 'PRG', 'name': 'Prague'},
#     'quality': []},
#    'number': 'KQ 1359',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXN', 'modeS': '484166', 'model': 'Boeing 737'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFLL', 'iata': 'LYS', 'name': 'Lyon'},
#     'quality': []},
#    'number': 'KQ 1419',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 195-E2'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '2',
#     'checkInDesk': '9-16',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LLBG',
#      'iata': 'TLV',
#      'name': 'Tel Aviv Yafo'},
#     'quality': []},
#    'number': 'KQ 1461',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXR', 'modeS': '48418C', 'model': 'Boeing 737'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LEVC', 'iata': 'VLC', 'name': 'Valencia'},
#     'quality': []},
#    'number': 'KQ 1501',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LIPZ', 'iata': 'VCE', 'name': 'Venice'},
#     'quality': []},
#    'number': 'KQ 1659',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:40+01:00',
#     'actualTimeLocal': '2022-11-05 20:40+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:40Z',
#     'actualTimeUtc': '2022-11-05 19:40Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDH', 'iata': 'HAM', 'name': 'Hamburg'},
#     'quality': []},
#    'number': 'KQ 1789',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXK', 'modeS': '484163', 'model': 'Boeing 737'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDB', 'iata': 'BER', 'name': 'Berlin'},
#     'quality': []},
#    'number': 'KQ 1835',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCA', 'modeS': '484CB4', 'model': 'Boeing 737'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'quality': []},
#    'number': 'KQ 1849',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCE', 'modeS': '484FDF', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse'},
#     'quality': []},
#    'number': 'KQ 1991',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'Kenya Airways'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:50+01:00',
#     'actualTimeLocal': '2022-11-05 20:50+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:50Z',
#     'actualTimeUtc': '2022-11-05 19:50Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'ESGG', 'iata': 'GOT', 'name': 'Goteborg'},
#     'quality': []},
#    'number': 'MF 9673',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXW', 'modeS': '484555', 'model': 'Boeing 737'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFLL', 'iata': 'LYS', 'name': 'Lyon'},
#     'quality': []},
#    'number': 'MF 9685',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 195-E2'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:25+01:00',
#     'actualTimeLocal': '2022-11-05 20:25+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:25Z',
#     'actualTimeUtc': '2022-11-05 19:25Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFBD',
#      'iata': 'BOD',
#      'name': 'Bordeaux/Mérignac'},
#     'quality': []},
#    'number': 'MF 9691',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LIPZ', 'iata': 'VCE', 'name': 'Venice'},
#     'quality': []},
#    'number': 'MF 9703',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LEVC', 'iata': 'VLC', 'name': 'Valencia'},
#     'quality': []},
#    'number': 'MF 9720',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDB', 'iata': 'BER', 'name': 'Berlin'},
#     'quality': []},
#    'number': 'MF 9727',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCA', 'modeS': '484CB4', 'model': 'Boeing 737'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LOWW', 'iata': 'VIE', 'name': 'Vienna'},
#     'quality': []},
#    'number': 'MF 9729',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCE', 'modeS': '484FDF', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'number': 'MF 9799',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:30+01:00',
#     'actualTimeLocal': '2022-11-05 20:30+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:30Z',
#     'actualTimeUtc': '2022-11-05 19:30Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EFHK', 'iata': 'HEL', 'name': 'Helsinki'},
#     'quality': []},
#    'number': 'MF 9917',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCL', 'modeS': '485A35', 'model': 'Boeing 737-800'},
#    'airline': {'name': 'Xiamen'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:40+01:00',
#     'actualTimeLocal': '2022-11-05 20:40+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:40Z',
#     'actualTimeUtc': '2022-11-05 19:40Z',
#     'terminal': '3',
#     'checkInDesk': '20',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'OMAA',
#      'iata': 'AUH',
#      'name': 'Abu Dhabi Island and Internal Islands City'},
#     'quality': []},
#    'number': 'MH 5230',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'Malaysia'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:45+01:00',
#     'actualTimeLocal': '2022-11-05 20:45+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:45Z',
#     'actualTimeUtc': '2022-11-05 19:45Z',
#     'terminal': '2',
#     'checkInDesk': '9-16',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'WMKK',
#      'iata': 'KUL',
#      'name': 'Kuala Lumpur'},
#     'quality': []},
#    'number': 'MH 5631',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BQF', 'modeS': '48436D', 'model': 'Boeing 777'},
#    'airline': {'name': 'Malaysia'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:25+01:00',
#     'actualTimeLocal': '2022-11-05 20:25+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:25Z',
#     'actualTimeUtc': '2022-11-05 19:25Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFPG', 'iata': 'CDG', 'name': 'Paris'},
#     'quality': []},
#    'number': 'MK 9397',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'F-GTAU', 'modeS': '394C14', 'model': 'Airbus A321'},
#    'airline': {'name': 'Air Mauritius'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFLL', 'iata': 'LYS', 'name': 'Lyon'},
#     'quality': []},
#    'number': 'MU 1561',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 195-E2'},
#    'airline': {'name': 'China Eastern'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFMN', 'iata': 'NCE', 'name': 'Nice'},
#     'quality': []},
#    'number': 'MU 1563',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'China Eastern'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:25+01:00',
#     'actualTimeLocal': '2022-11-05 20:25+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:25Z',
#     'actualTimeUtc': '2022-11-05 19:25Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LFBD',
#      'iata': 'BOD',
#      'name': 'Bordeaux/Mérignac'},
#     'quality': []},
#    'number': 'MU 1573',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'China Eastern'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDB', 'iata': 'BER', 'name': 'Berlin'},
#     'quality': []},
#    'number': 'MU 1599',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BCA', 'modeS': '484CB4', 'model': 'Boeing 737'},
#    'airline': {'name': 'China Eastern'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:40+01:00',
#     'actualTimeLocal': '2022-11-05 20:40+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:40Z',
#     'actualTimeUtc': '2022-11-05 19:40Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'EDDH', 'iata': 'HAM', 'name': 'Hamburg'},
#     'quality': []},
#    'number': 'MU 1609',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BXK', 'modeS': '484163', 'model': 'Boeing 737'},
#    'airline': {'name': 'China Eastern'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LIPZ', 'iata': 'VCE', 'name': 'Venice'},
#     'quality': []},
#    'number': 'MU 1826',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'China Eastern'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:35+01:00',
#     'actualTimeLocal': '2022-11-05 20:35+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:35Z',
#     'actualTimeUtc': '2022-11-05 19:35Z',
#     'terminal': '1',
#     'checkInDesk': '6-8',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'LEVC', 'iata': 'VLC', 'name': 'Valencia'},
#     'quality': []},
#    'number': 'MU 1849',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'China Eastern'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:00+01:00',
#     'actualTimeLocal': '2022-11-05 20:00+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:00Z',
#     'actualTimeUtc': '2022-11-05 19:00Z',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'UTAK',
#      'iata': 'KRW',
#      'name': 'Krasnovodsk'},
#     'quality': []},
#    'number': 'N8 805',
#    'status': 'Canceled',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': True,
#    'aircraft': {'reg': 'N952CA',
#     'modeS': 'AD3C48',
#     'model': 'Boeing 747-400 Freighter'},
#    'airline': {'name': 'National'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:40+01:00',
#     'actualTimeLocal': '2022-11-05 20:40+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:40Z',
#     'actualTimeUtc': '2022-11-05 19:40Z',
#     'terminal': '3',
#     'checkInDesk': '20',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'OMAA',
#      'iata': 'AUH',
#      'name': 'Abu Dhabi Island and Internal Islands City'},
#     'quality': []},
#    'number': 'PK 4078',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'Pakistan International'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'terminal': '2',
#     'checkInDesk': '9-16',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'VTBS', 'iata': 'BKK', 'name': 'Bangkok'},
#     'quality': []},
#    'number': 'QF 4214',
#    'status': 'Expected',
#    'codeshareStatus': 'IsCodeshared',
#    'isCargo': False,
#    'aircraft': {'reg': 'PH-BVG', 'modeS': '484CBB', 'model': 'Boeing 777'},
#    'airline': {'name': 'Qantas'}},
#   {'departure': {'scheduledTimeLocal': '2022-11-05 20:55+01:00',
#     'actualTimeLocal': '2022-11-05 20:55+01:00',
#     'scheduledTimeUtc': '2022-11-05 19:55Z',
#     'actualTimeUtc': '2022-11-05 19:55Z',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'airport': {'icao': 'KORD', 'iata': 'ORD', 'name': 'Chicago'},
#     'quality': []},
#    'number': 'QR 8101',
#    'status': 'Expected',
#    'codeshareStatus': 'IsOperator',
#    'isCargo': True,
#    'aircraft': {'model': 'Boeing 777-200LR Freighter'},
#    'airline': {'name': 'Qatar Airways'}},
# ...
#     'scheduledTimeLocal': '2022-11-05 23:55+08:00',
#     'actualTimeLocal': '2022-11-05 23:55+08:00',
#     'scheduledTimeUtc': '2022-11-05 15:55Z',
#     'actualTimeUtc': '2022-11-05 15:55Z',
#     'terminal': '3',
#     'checkInDesk': '03',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 06:45+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:45Z',
#     'quality': ['Basic']},
#    'number': 'SQ 324',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A350-900'},
#    'airline': {'name': 'Singapore'}},
#   {'departure': {'airport': {'icao': 'KBOS', 'iata': 'BOS', 'name': 'Boston'},
#     'scheduledTimeLocal': '2022-11-05 19:40-04:00',
#     'scheduledTimeUtc': '2022-11-05 23:40Z',
#     'terminal': 'E',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:55+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:55Z',
#     'quality': ['Basic']},
#    'number': 'DL 258',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A330-300'},
#    'airline': {'name': 'Delta Air Lines'}},
#   {'departure': {'airport': {'icao': 'OMDB',
#      'iata': 'DXB',
#      'name': 'Dubai City'},
#     'scheduledTimeLocal': '2022-11-06 03:20+04:00',
#     'scheduledTimeUtc': '2022-11-05 23:20Z',
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:50+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:50Z',
#     'quality': ['Basic']},
#    'number': 'EK 145',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 777-300ER'},
#    'airline': {'name': 'Emirates'}},
#   {'departure': {'airport': {'icao': 'EKCH',
#      'iata': 'CPH',
#      'name': 'Copenhagen'},
#     'scheduledTimeLocal': '2022-11-06 06:00+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:00Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:25+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:25Z',
#     'quality': ['Basic']},
#    'number': 'KL 1124',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-900'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'ESGG',
#      'iata': 'GOT',
#      'name': 'Goteborg'},
#     'scheduledTimeLocal': '2022-11-06 06:00+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:00Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:35+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:35Z',
#     'quality': ['Basic']},
#    'number': 'KL 1152',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'ESSL',
#      'iata': 'LPI',
#      'name': 'Linköping'},
#     'scheduledTimeLocal': '2022-11-06 06:05+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:05Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:55+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:55Z',
#     'quality': ['Basic']},
#    'number': 'KL 1178',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'ENBR', 'iata': 'BGO', 'name': 'Bergen'},
#     'scheduledTimeLocal': '2022-11-06 06:10+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:10Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:50+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:50Z',
#     'quality': ['Basic']},
#    'number': 'KL 1184',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-700'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'LFBD',
#      'iata': 'BOD',
#      'name': 'Bordeaux/Mérignac'},
#     'scheduledTimeLocal': '2022-11-06 06:00+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:00Z',
#     'terminal': 'B',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:50+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:50Z',
#     'quality': ['Basic']},
#    'number': 'KL 1312',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EKYT', 'iata': 'AAL', 'name': 'Aalborg'},
#     'scheduledTimeLocal': '2022-11-06 06:00+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:00Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:25+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:25Z',
#     'quality': ['Basic']},
#    'number': 'KL 1328',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EKBI', 'iata': 'BLL', 'name': 'Billund'},
#     'scheduledTimeLocal': '2022-11-06 06:05+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:05Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:20+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:20Z',
#     'quality': ['Basic']},
#    'number': 'KL 1340',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'LKPR', 'iata': 'PRG', 'name': 'Prague'},
#     'scheduledTimeLocal': '2022-11-06 06:00+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:00Z',
#     'terminal': '2',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:35+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:35Z',
#     'quality': ['Basic']},
#    'number': 'KL 1350',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'LFRS', 'iata': 'NTE', 'name': 'Nantes'},
#     'scheduledTimeLocal': '2022-11-06 06:10+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:10Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:50+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:50Z',
#     'quality': ['Basic']},
#    'number': 'KL 1454',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EBBR',
#      'iata': 'BRU',
#      'name': 'Brussels'},
#     'scheduledTimeLocal': '2022-11-06 06:15+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:15Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:10+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:10Z',
#     'quality': ['Basic']},
#    'number': 'KL 1720',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'ELLX',
#      'iata': 'LUX',
#      'name': 'Luxembourg'},
#     'scheduledTimeLocal': '2022-11-06 06:10+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:10Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:20+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:20Z',
#     'quality': ['Basic']},
#    'number': 'KL 1736',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EDDW', 'iata': 'BRE', 'name': 'Bremen'},
#     'scheduledTimeLocal': '2022-11-06 06:00+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:00Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:00+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:00Z',
#     'quality': ['Basic']},
#    'number': 'KL 1750',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EDDH', 'iata': 'HAM', 'name': 'Hamburg'},
#     'scheduledTimeLocal': '2022-11-06 06:15+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:15Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:20+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:20Z',
#     'quality': ['Basic']},
#    'number': 'KL 1776',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EDDB', 'iata': 'BER', 'name': 'Berlin'},
#     'scheduledTimeLocal': '2022-11-06 06:00+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:00Z',
#     'terminal': '1',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:25+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:25Z',
#     'quality': ['Basic']},
#    'number': 'KL 1818',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 737-800'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EDDL',
#      'iata': 'DUS',
#      'name': 'Duesseldorf'},
#     'scheduledTimeLocal': '2022-11-06 06:10+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:10Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:05+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:05Z',
#     'quality': ['Basic']},
#    'number': 'KL 1852',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EDDS',
#      'iata': 'STR',
#      'name': 'Stuttgart'},
#     'scheduledTimeLocal': '2022-11-06 06:00+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:00Z',
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:30+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:30Z',
#     'quality': ['Basic']},
#    'number': 'KL 1866',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 190'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'EDDV', 'iata': 'HAJ', 'name': 'Hanover'},
#     'scheduledTimeLocal': '2022-11-06 06:10+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:10Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:15+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:15Z',
#     'quality': ['Basic']},
#    'number': 'KL 1900',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'LFSB',
#      'iata': 'BSL',
#      'name': 'Bâle/Mulhouse'},
#     'scheduledTimeLocal': '2022-11-06 06:20+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:20Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:50+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:50Z',
#     'quality': ['Basic']},
#    'number': 'KL 1984',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'OEDF',
#      'iata': 'DMM',
#      'name': 'Ad Dammam'},
#     'scheduledTimeLocal': '2022-11-06 02:20+03:00',
#     'scheduledTimeUtc': '2022-11-05 23:20Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:10+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:10Z',
#     'quality': ['Basic']},
#    'number': 'KL 425',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Airbus A330-300'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'HTDA',
#      'iata': 'DAR',
#      'name': 'Dar es Salaam'},
#     'scheduledTimeLocal': '2022-11-05 23:59+03:00',
#     'scheduledTimeUtc': '2022-11-05 20:59Z',
#     'terminal': '3',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:15+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:15Z',
#     'quality': ['Basic']},
#    'number': 'KL 569',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'CYYZ', 'iata': 'YYZ', 'name': 'Toronto'},
#     'scheduledTimeLocal': '2022-11-05 19:10-04:00',
#     'actualTimeLocal': '2022-11-05 19:10-04:00',
#     'scheduledTimeUtc': '2022-11-05 23:10Z',
#     'actualTimeUtc': '2022-11-05 23:10Z',
#     'terminal': '3',
#     'gate': 'C34',
#     'quality': ['Basic', 'Live']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:15+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:15Z',
#     'quality': ['Basic']},
#    'number': 'KL 692',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'TNCC',
#      'iata': 'CUR',
#      'name': 'Willemstad'},
#     'scheduledTimeLocal': '2022-11-05 17:35-04:00',
#     'scheduledTimeUtc': '2022-11-05 21:35Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:40+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:40Z',
#     'quality': ['Basic']},
#    'number': 'KL 734',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 777-200'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'VTBS', 'iata': 'BKK', 'name': 'Bangkok'},
#     'scheduledTimeLocal': '2022-11-06 00:30+07:00',
#     'scheduledTimeUtc': '2022-11-05 17:30Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:10+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:10Z',
#     'quality': ['Basic']},
#    'number': 'KL 804',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 777-300ER'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'VTBS', 'iata': 'BKK', 'name': 'Bangkok'},
#     'scheduledTimeLocal': '2022-11-06 00:40+07:00',
#     'scheduledTimeUtc': '2022-11-05 17:40Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:15+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:15Z',
#     'quality': ['Basic']},
#    'number': 'KL 844',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 787-9'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'ENZV',
#      'iata': 'SVG',
#      'name': 'Stavanger'},
#     'scheduledTimeLocal': '2022-11-06 06:00+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:00Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:35+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:35Z',
#     'quality': ['Basic']},
#    'number': 'KL 1196',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'ENCN', 'iata': 'KRS', 'name': 'Kjevik'},
#     'scheduledTimeLocal': '2022-11-06 06:00+01:00',
#     'scheduledTimeUtc': '2022-11-06 05:00Z',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:30+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:30Z',
#     'quality': ['Basic']},
#    'number': 'KL 1206',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Embraer 175'},
#    'airline': {'name': 'KLM'}},
#   {'departure': {'airport': {'icao': 'KEWR', 'iata': 'EWR', 'name': 'Newark'},
#     'scheduledTimeLocal': '2022-11-05 19:05-04:00',
#     'scheduledTimeUtc': '2022-11-05 23:05Z',
#     'terminal': 'C',
#     'quality': ['Basic']},
#    'arrival': {'scheduledTimeLocal': '2022-11-06 07:15+01:00',
#     'scheduledTimeUtc': '2022-11-06 06:15Z',
#     'quality': ['Basic']},
#    'number': 'UA 70',
#    'status': 'Unknown',
#    'codeshareStatus': 'Unknown',
#    'isCargo': False,
#    'aircraft': {'model': 'Boeing 777'},
#    'airline': {'name': 'United'}}]}

# %%
arrivals_df = pd.json_normalize(response.json()["arrivals"])

# %%
arrivals_df.columns
# Out:
# Index(['number', 'status', 'codeshareStatus', 'isCargo',
#        'departure.airport.icao', 'departure.airport.iata',
#        'departure.airport.name', 'departure.quality',
#        'arrival.scheduledTimeLocal', 'arrival.actualTimeLocal',
#        'arrival.runwayTimeLocal', 'arrival.scheduledTimeUtc',
#        'arrival.actualTimeUtc', 'arrival.runwayTimeUtc', 'arrival.quality',
#        'aircraft.model', 'airline.name', 'departure.scheduledTimeLocal',
#        'departure.actualTimeLocal', 'departure.scheduledTimeUtc',
#        'departure.actualTimeUtc', 'departure.terminal',
#        'departure.checkInDesk', 'departure.gate'],
#       dtype='object')

# %%
arrivals_new_df = arrivals_df[['number', "status", 'arrival.scheduledTimeLocal', 'aircraft.model', 'airline.name', 'codeshareStatus']]

# %%
arrivals_new_df
# Out:
#       number    status arrival.scheduledTimeLocal             aircraft.model  \
# 0    AM 6517  Expected     2022-11-05 20:20+01:00  Boeing 737-800 (winglets)
# 1    EY 7017  Expected     2022-11-05 20:20+01:00  Boeing 737-800 (winglets)
# 2     BA 442  Expected     2022-11-05 20:30+01:00                Airbus A320
# 3    GA 8830  Expected     2022-11-05 20:20+01:00  Boeing 737-800 (winglets)
# 4    HV 5228  Expected     2022-11-05 20:45+01:00  Boeing 737-800 (winglets)
# ..       ...       ...                        ...                        ...
# 111   KL 804   Unknown     2022-11-06 07:10+01:00           Boeing 777-300ER
# 112   KL 844   Unknown     2022-11-06 07:15+01:00               Boeing 787-9
# 113  KL 1196   Unknown     2022-11-06 07:35+01:00                        NaN
# 114  KL 1206   Unknown     2022-11-06 07:30+01:00                Embraer 175
# 115    UA 70   Unknown     2022-11-06 07:15+01:00                 Boeing 777
#
#          airline.name codeshareStatus
# 0          Aeromexico    IsCodeshared
# 1      Etihad Airways    IsCodeshared
# 2     British Airways      IsOperator
# 3    Garuda Indonesia    IsCodeshared
# 4           Transavia      IsOperator
# ..                ...             ...
# 111               KLM         Unknown
# 112               KLM         Unknown
# 113               KLM         Unknown
# 114               KLM         Unknown
# 115            United         Unknown
#
# [116 rows x 6 columns]

# %%
arrivals_new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   number                      116 non-null    object
#  1   status                      116 non-null    object
#  2   arrival.scheduledTimeLocal  116 non-null    object
#  3   aircraft.model              114 non-null    object
#  4   airline.name                116 non-null    object
#  5   codeshareStatus             116 non-null    object
# dtypes: object(6)
# memory usage: 5.6+ KB

# %%
arrivals_new_df["arrival.scheduledTimeLocal"] = pd.to_datetime(arrivals_new_df["arrival.scheduledTimeLocal"])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
arrivals_new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 6 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   number                      116 non-null    object
#  1   status                      116 non-null    object
#  2   arrival.scheduledTimeLocal  116 non-null    datetime64[ns, pytz.FixedOffset(60)]
#  3   aircraft.model              114 non-null    object
#  4   airline.name                116 non-null    object
#  5   codeshareStatus             116 non-null    object
# dtypes: datetime64[ns, pytz.FixedOffset(60)](1), object(5)
# memory usage: 5.6+ KB

# %%
today = datetime.now().date()

# %%
today
# Out:
# datetime.date(2022, 11, 4)

# %%
tomorrow = today + timedelta(days=1)

# %%
tomorrow
# Out:
# datetime.date(2022, 11, 5)

# %%
icao_codes = ["EDDB", "EDDM", "EDDP", "EDDK"]

# %%
def arrivals(codes):

  arrivals_list = []

  today = datetime.now().date()
  tomorrow = today + timedelta(days=1)
  
  morning = {"start_time": "00:00", "end_time": "12:00"}
  afternoon = {"start_time": "12:00", "end_time": "23:59"}
  times = [morning, afternoon]

  for code in codes:
    for time in times:

      url = f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/{code}/{tomorrow}T{time['start_time']}/{tomorrow}T{time['end_time']}"

      querystring = {"withLeg":"true","withCancelled":"true","withCodeshared":"true","withCargo":"true","withPrivate":"true","withLocation":"false"}

      headers = {
        "X-RapidAPI-Key": "b409d718a7mshf46e85a187fe9c0p179890jsn8fd66df75a29",
        "X-RapidAPI-Host": "aerodatabox.p.rapidapi.com"
      }

      response = requests.request("GET", url, headers=headers, params=querystring)
      arrivals_df = pd.json_normalize(response.json()["arrivals"]).copy()

      arrivals_new_df = arrivals_df.loc[:, ['arrival.scheduledTimeLocal', 'number', "status", 'aircraft.model', 'airline.name', 'codeshareStatus']]

      arrivals_new_df["arrival.scheduledTimeLocal"] = pd.to_datetime(arrivals_new_df["arrival.scheduledTimeLocal"])

      #arrivals_new_df["arrival_icao"] = code

      arrivals_new_df.insert(0, "arrival_icao", code)

      arrivals_list.append(arrivals_new_df)

  return pd.concat(arrivals_list)

# %%
df_ = arrivals(icao_codes)

# %%
df_["codeshareStatus"].unique()
# Out:
# array(['IsOperator', 'Unknown'], dtype=object)

# %%
morning = {"start_time": "00:00", "end_time": "12:00"}
afternoon = {"start_time": "12:00", "end_time": "00:00"}
times = [morning, afternoon]

for time in times:
  print(f"https://aerodatabox.p.rapidapi.com/flights/airports/icao/2022-11-05T{time['start_time']}/2022-11-06T{time['end_time']}")
# Out:
# https://aerodatabox.p.rapidapi.com/flights/airports/icao/2022-11-05T00:00/2022-11-06T12:00
# https://aerodatabox.p.rapidapi.com/flights/airports/icao/2022-11-05T12:00/2022-11-06T00:00

# %%
df_
# Out:
#    arrival_icao arrival.scheduledTimeLocal   number   status   aircraft.model  \
# 0          EDDB  2022-11-05 06:45:00+01:00  FR 1571  Unknown   Boeing 737-800
# 1          EDDB  2022-11-05 07:55:00+01:00   BT 211  Unknown  Airbus A220-300
# 2          EDDB  2022-11-05 07:55:00+01:00     EW 6  Unknown      Airbus A320
# 3          EDDB  2022-11-05 07:55:00+01:00   LH 170  Unknown      Airbus A320
# 4          EDDB  2022-11-05 07:55:00+01:00   UA 962  Unknown   Boeing 767-300
# ..          ...                        ...      ...      ...              ...
# 34         EDDK  2022-11-05 23:25:00+01:00  LH 1992  Unknown      Airbus A319
# 35         EDDK  2022-11-05 23:35:00+01:00  PC 1013  Unknown   Boeing 737-800
# 36         EDDK  2022-11-05 23:45:00+01:00   XQ 116  Unknown   Boeing 737-800
# 37         EDDK  2022-11-05 23:55:00+01:00   XQ 118  Unknown   Boeing 737-800
# 38         EDDK  2022-11-05 21:10:00+01:00  FR 7211  Unknown      Airbus A320
#
#    airline.name codeshareStatus
# 0       Ryanair      IsOperator
# 1    Air Baltic         Unknown
# 2     Eurowings         Unknown
# 3     Lufthansa         Unknown
# 4        United         Unknown
# ..          ...             ...
# 34    Lufthansa         Unknown
# 35      Pegasus         Unknown
# 36   SunExpress         Unknown
# 37   SunExpress         Unknown
# 38      Ryanair         Unknown
#
# [616 rows x 7 columns]
